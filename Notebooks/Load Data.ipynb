# %% [markdown]
# ## 📂 Load Data
#
# This script loads the raw Airbnb dataset into a Pandas DataFrame using a clean, reliable workflow suitable for analysis and reproducible projects.
#
# ### What this script does
# - Loads the CSV file using a **relative path**, so it works on any machine or GitHub environment.
# - Prints a quick summary showing how many rows and columns were loaded.
# - Displays the first few rows to confirm the dataset structure.
#
# ### How to run
# ```bash
# python load_data.py

# %% [raw]
# # Directory containing the raw CSV inputs
# import pandas as pd
# import os

# %%
# Relative path to the dataset inside the project structure
CSV_PATH = os.path.join("data", "Airbnb_Open_Data.csv")
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[1], line 2
#       1 # Relative path to the dataset inside the project structure
# ----> 2 CSV_PATH = os.path.join("data", "Airbnb_Open_Data.csv")
#
# NameError: name 'os' is not defined

# %%
def load_data(path):
    """Load CSV into a DataFrame with a quick sanity check."""
    df = pd.read_csv(path)
    print(f"Loaded: {path} | Rows: {len(df)}, Columns: {len(df.columns)}")
    return df

# %%
if __name__ == "__main__":
    df = load_data(CSV_PATH)
    print("\n--- Preview ---")
    print(df.head())
# Out:
# ----------------------------------------------------------------
# NameError                      Traceback (most recent call last)
# Cell In[2], line 2
#       1 if __name__ == "__main__":
# ----> 2     df = load_data(CSV_PATH)
#       3     print("\n--- Preview ---")
#       4     print(df.head())
#
# NameError: name 'load_data' is not defined
